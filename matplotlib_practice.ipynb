# %%
# Import Dependencies

import matplotlib.pyplot as plt

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
plt.plot(x_axis,y_axis)

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis)

# %%
fig=plt.figure()
ax=fig.add_subplot()
ax.plot(x_axis,y_axis)

# %%
ax=plt.axes()
ax.plot(x_axis,y_axis)

# %%
plt.plot(x_axis,y_axis,label="Boston",marker="*",color="red",linewidth=2)
plt.xlabel("Months")
plt.ylabel("Fares($)")
plt.title("Pyber Fare by Month")
plt.legend()
plt.ylim(0,50)
plt.grid()

# %%
fig,ax=plt.subplots()
ax.plot(x_axis,y_axis,label='Boston',linewidth=2,marker="*",color="green")
ax.legend()
ax.grid()
ax.set_xlabel("Months")
ax.set_ylabel("Fares($)")
ax.set_title("Pyber Fare By Month")
# Out:
# Text(0.5, 1.0, 'Pyber Fare By Month')

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
plt.barh(x_axis,y_axis,label="Boston",color="magenta")
plt.xlabel("Date")
plt.ylabel("Fares($)")
plt.legend()
plt.title("Pyber Fare by Month")
plt.gca().invert_yaxis()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
plt.bar(x_axis,y_axis,label="Boston",color="orange")
plt.xlabel("Date")
plt.ylabel("Fares($)")
plt.legend()
plt.title("Pyber Fare by Month")
# Out:
# Text(0.5, 1.0, 'Pyber Fare by Month')

# %%
fig,ax=plt.subplots()
ax.barh(x_axis,y_axis,color="cyan",label="Chicago")
ax.legend()
ax.set_xlabel("Fares($)")
ax.set_ylabel("Months")
ax.set_title("Pyber Fare By Month")
plt.gca().invert_yaxis()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# plt.plot(x_axis,y_axis,'x')
plt.scatter(x_axis,y_axis,s=y_axis)
y_axis_large=list()
for i in y_axis:
    y_axis_large.append(i*3)

    
plt.scatter(x_axis,y_axis,s=y_axis_large)

# %%
plt.scatter(x_axis,y_axis,s=[i*3 for i in y_axis])

# %%
fig,ax=plt.subplots()
ax.scatter(y_axis,x_axis,c="blue",alpha=0.2,edgecolor="red",s=[i*5 for i in y_axis],label="Boston")
ax.set_title("Pyber Fare by Month")
ax.set_xlabel("Months")
ax.set_ylabel("Fares($)")
ax.legend()
plt.gca().invert_yaxis()

# %%
plt.scatter(y_axis,x_axis,c="red",label="Chiacago")
plt.xlabel("Fares($)")
plt.ylabel("Months")
plt.title("Pyber Fare By Month")
plt.legend()
plt.gca().invert_yaxis()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]
# Assign 12 colors, one for each month.
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
fig,ax=plt.subplots(figsize=(8,8))
ax.pie(y_axis,labels=x_axis,shadow=True,counterclock=False,startangle=-270,autopct="%.1f%%",colors=colors,explode=explode_values)
plt.show()

# %%
# %matplotlib inline

# %%
# Import dependencies.
import matplotlib.pyplot as plt
import statistics
import numpy as np
from matplotlib.ticker import MultipleLocator
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

stdev=statistics.stdev(y_axis)
plt.errorbar(x_axis,y_axis,yerr=stdev,capsize=3)
plt.yticks(np.arange(0,51,5))
# Out:
# ([<matplotlib.axis.YTick at 0x22b1d2b0340>,
#   <matplotlib.axis.YTick at 0x22b1d2b9dc0>,
#   <matplotlib.axis.YTick at 0x22b1d2b9220>,
#   <matplotlib.axis.YTick at 0x22b1e5f0d00>,
#   <matplotlib.axis.YTick at 0x22b1a7004c0>,
#   <matplotlib.axis.YTick at 0x22b1a700c10>,
#   <matplotlib.axis.YTick at 0x22b1a71c3a0>,
#   <matplotlib.axis.YTick at 0x22b1a71caf0>,
#   <matplotlib.axis.YTick at 0x22b1a719280>,
#   <matplotlib.axis.YTick at 0x22b1a71c5b0>,
#   <matplotlib.axis.YTick at 0x22b1a7001c0>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
fig,ax=plt.subplots()
ax.errorbar(x_axis,y_axis,capsize=3,yerr=stdev)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.bar(x_axis,y_axis,capsize=3,yerr=stdev)
# Out:
# <BarContainer object of 12 artists>

# %%
fig,ax=plt.subplots()
# ax.bar(x_axis,y_axis,capsize=3,yerr=stdev)
ax.barh(x_axis,y_axis)
ax.set_xticks(np.arange(0,51,5))
ax.xaxis.set_minor_locator(MultipleLocator(1))
